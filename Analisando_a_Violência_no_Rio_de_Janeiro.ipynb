# %% [markdown]
# <a href="https://colab.research.google.com/github/roberto-paixao/analise-violencia-do-rio/blob/main/Analisando_a_Viol%C3%AAncia_no_Rio_de_Janeiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisando a Violência no Rio de Janeiro
# ---
# <br>
#
# Sendo o maior destino turístico internacional do Brasil, o **Rio de Janeiro**, popularmente referida apenas como "Rio", é a cidade brasileira mais conhecida no exterior. É a segunda maior metrópole do Brasil depois de São Paulo, sua população, segundo o IBGE em 2020, era cerca de 7 milhões habitantes aproximadamente.
#
# O Rio é popular pelas praias de Copacabana e Ipanema, pela estátua de 38 metros de altura do Cristo Redentor no topo do Corcovado, e pelo Pão de Açúcar, é conhecida também pelas suas grandes favelas e pelo maior Carnaval do mundo.
#
#
# <p align="center">
#     <img alt="Rio de Janeiro" width="70%" src="https://revistacapitaleconomico.com.br/wp-content/uploads/2019/11/melhor-lugar-para-se-morar-no-rio-de-janeiro.jpg"/>
# </p>
#
# Entretanto, como toda outra cidade do Brasil e do mundo, nem tudo é um mar de rosas, a violência é um problema recorrente nas grandes metrópoles e o Rio não é uma exceção a essa regra, com a violência se tornando um problema cada vez maior no Brasil, todos os dias são noticiados crimes das mais diversas proporções em todos os estados.
#
# Hoje em dia, com as leis de acesso à informação e a conscientização dos órgãos públicos, alguns estados disponibilizam diversas fontes de dados sobre a segurança pública.
#
# O governo do Rio de Janeiro criou o portal [ISPDados](http://www.ispdados.rj.gov.br/), que é uma página de __Dados Abertos do Instituto de Segurança Pública__ onde podemos acessar as bases de dados de registros criminais e de atividade policial do estado do Rio de Janeiro.
#
#
# Usaremos essa fonte de dados para fazermos uma análise exploratória sobre a violência no Rio de Janeiro.
# <p align="center">
#     <img alt="Rio-logo" width="150" src="https://static.vecteezy.com/ti/vetor-gratis/p3/235858-fundo-de-tracos-de-tinta-grunge-rio-de-janeiro-brasil-gr%C3%A1tis-vetor.jpg">
# </p>
#
# ---
# <br>

# %% [markdown]
# ## Obtenção dos Dados
#
# O portal ISPDados é uma página de Dados Abertos do Instituto de Segurança Pública do Rio de Janeiro, onde podemos [acessar as bases de dados](http://www.ispdados.rj.gov.br/estatistica.html) de registros criminais e de atividade policial do estado do Rio de Janeiro. De acordo com o site, as estatísticas são construídas a partir dos Registros de Ocorrência (RO) lavrados nas delegacias da Secretaria de Estado de Polícia Civil do Rio de Janeiro (SEPOL), além de informações complementares de órgãos específicos da Secretaria de Estado de Polícia Militar do Rio de Janeiro (SEPM).
#
# As informações sobre os RO são submetidos ao controle de qualidade realizado pela Corregedoria Geral de Polícia (CGPOL) antes de serem consolidados no ISP. As estatísticas produzidas baseiam-se na data em que foi confeccionado o Registro de Ocorrência.
#
#  A base de dados (`csv`) que usaremos poderá ser baixado diretamente pelo [link](https://raw.githubusercontent.com/roberto-paixao/Analise_Violencia_do_Rio/main/data/DOMensalEstadoDesde1991.csv) e possui informações sobre os crimes registrados desde 1991 até 2021. Para facilitar o entendimento do significado dos dados presentes na base de dados, o portal disponibiliza um [dicionário de dados](https://www.ispdados.rj.gov.br:4432/Arquivos/BaseDpDicionarioDeVariaveis.xlsx) onde descreve a informação que cada atributo possui, que pode ser conferido na tabela abaixo:
#
# |Variável|Descrição|Contagem por|
# |--------|---------|--------|
# |ano|Ano da comunicação da ocorrência| - |
# |mes|Mês da comunicação da ocorrência| - |
# |fase|2 - Consolidado sem errata    3 - Consolidado com errata| - |
# |hom_doloso|Homicídio doloso|vítima|
# |lesao_corp_morte|Lesão corporal seguida de morte|vítima|
# |latrocinio|Latrocínio (roubo seguido de morte)|vítima|
# |cvli|Crimes violentos letais intencionais|vítima|
# |hom_por_interv_policial|Morte por intervenção de agente do Estado|vítima|
# |letalidade_violenta|Letalidade violenta|vítima|
# |tentat_hom|Tentativa de homicídio|vítima|
# |lesao_corp_dolosa|Lesão corporal dolosa|vítima|
# |estupro|Estupro|vítima|
# |hom_culposo|Homicídio culposo (trânsito)|vítima|
# |lesao_corp_culposa|Lesão corporal culposa (trânsito)|vítima|
# |roubo_transeunte|Roubo a transeunte|caso|
# |roubo_celular|Roubo de telefone celular|caso|
# |roubo_em_coletivo|Roubo em coletivo|caso|
# |roubo_rua|Roubo de rua|caso|
# |roubo_veiculo|Roubo de veículo|caso|
# |roubo_carga|Roubo de carga|caso|
# |roubo_comercio|Roubo a estabelecimento comercial|caso|
# |roubo_residencia|Roubo a residência|caso|
# |roubo_banco|Roubo a banco|caso|
# |roubo_cx_eletronico|Roubo de caixa eletrônico|caso|
# |roubo_conducao_saque|Roubo com condução da vítima para saque em instituição financeira|caso|
# |roubo_apos_saque|Roubo após saque em instituição financeira|caso|
# |roubo_bicicleta|Roubo de bicicleta|caso|
# |outros_roubos|Outros roubos que não os listados acima|caso|
# |total_roubos|Total de roubos|caso|
# |furto_veiculos|Furto de veículo|caso|
# |furto_transeunte|Furto a transeunte|caso|
# |furto_coletivo|Furto em coletivo|caso|
# |furto_celular|Furto de telefone celular|caso|
# |furto_bicicleta|Furto de bicicleta|caso|
# |outros_furtos|Outros furtos que não os listados acima|caso|
# |total_furtos|Total de furtos|caso|
# |sequestro|Extorsão mediante sequestro (sequestro clássico)|vítima|
# |extorsao|Extorsão|caso|
# |sequestro_relampago|Extorsão com momentânea privação da liberdade (sequestro relâmpago)|vítima|
# |estelionato|Estelionato|caso|
# |apreensao_drogas|Apreensão de drogas|caso|
# |posse_drogas|Número de registros que possuem algum título referente a posse de drogas|caso|
# |trafico_drogas|Número de registros que possuem algum título referente a tráfico de drogas|caso|
# |apreensao_drogas_sem_autor|Número de registros que possuem algum título referente a apreensão de drogas sem autor|caso|
# |recuperacao_veiculos|Recuperação de veículo|caso|
# |apf|Auto de Prisão em Flagrante|autor|
# |aaapai|Auto de Apreensão de Adolescente por Prática de Ato Infracional|adolescente infrator|
# |cmp|Cumprimento de Mandado de Prisão|autor|
# |cmba|Cumprimento de Mandado de Busca e Apreensão|adolescente infrator|
# |ameaca|Ameaça|vítima|
# |pessoas_desaparecidas|Pessoas desaparecidas|vítima|
# |encontro_cadaver|Encontro de cadáver|vítima|
# |encontro_ossada|Encontro de ossada|vítima|
# |pol_militares_mortos_serv|Policiais Militares mortos em serviço|vítima|
# |pol_civis_mortos_serv|Policiais Civis mortos em serviço|vítima|
# |registro_ocorrencias|Registro de ocorrências|caso|
#
# <br>
#
# **Observação:** O dataset está atualizado até o mês de _Abril_ de 2021

# %% [markdown]
# ### Importando os dados
#
# Usaremos as seguintes bibliotecas:
# * `pandas` - Geração e manipulação de DataFrames.
# * `seaborn`, `matplotlib` - Visualização de dados.

# %%
# Importando os módulos necessários
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

# Configurações dos gráficos
figsize(12,8)
plt.rcParams["font.family"] = "sans-serif"

# Cores
LARANJA = "#FFA31A"
CINZA_TITULO = "#515151"
CINZA = "#9E9E9E"

# %%
# Gerando um DataFrame com os dados baixados.
DATA_PATH = "https://raw.githubusercontent.com/roberto-paixao/Analise_Violencia_do_Rio/main/data/DOMensalEstadoDesde1991.csv"


# O arquivo csv está separado por ';'
df = pd.read_csv(DATA_PATH, sep=';')

# %% [markdown]
# ## Análise Inicial dos Dados
#
# Primeiramente, para termos uma visão geral, veremos como está estruturado nosso `DataFrame`.

# %%
# Verificaremos o tamanho do DataFrame
print("Entradas: ", df.shape[0])
print("Atributos: ", df.shape[1])
# Out:
# Entradas:  364
# Atributos:  56

# %% [markdown]
# Veremos agora quais são esses atributos presentes no dataset.

# %%
# Exibindo o nome das colunas (Atributos)
df.columns.to_list()
# Out:
# ['ano',
#  'mes',
#  'hom_doloso',
#  'lesao_corp_morte',
#  'latrocinio',
#  'cvli',
#  'hom_por_interv_policial',
#  'letalidade_violenta',
#  'tentat_hom',
#  'lesao_corp_dolosa',
#  'estupro',
#  'hom_culposo',
#  'lesao_corp_culposa',
#  'roubo_transeunte',
#  'roubo_celular',
#  'roubo_em_coletivo',
#  'roubo_rua',
#  'roubo_veiculo',
#  'roubo_carga',
#  'roubo_comercio',
#  'roubo_residencia',
#  'roubo_banco',
#  'roubo_cx_eletronico',
#  'roubo_conducao_saque',
#  'roubo_apos_saque',
#  'roubo_bicicleta',
#  'outros_roubos',
#  'total_roubos',
#  'furto_veiculos',
#  'furto_transeunte',
#  'furto_coletivo',
#  'furto_celular',
#  'furto_bicicleta',
#  'outros_furtos',
#  'total_furtos',
#  'sequestro',
#  'extorsao',
#  'sequestro_relampago',
#  'estelionato',
#  'apreensao_drogas',
#  'posse_drogas',
#  'trafico_drogas',
#  'apreensao_drogas_sem_autor',
#  'recuperacao_veiculos',
#  'apf',
#  'aaapai',
#  'cmp',
#  'cmba',
#  'ameaca',
#  'pessoas_desaparecidas',
# ...

# %% [markdown]
# Uma vez conhecido os atributos de um _dataset_, é importante compreender o tipo de variável de cada atributo.
#
# Essa informação é importante e nos ajudará a direcionar nossos esforços na etapa de limpeza e tratamento dos dados.

# %%
# Verificando o tipo de cada atributo
df.dtypes
# Out:
# ano                            int64
# mes                            int64
# hom_doloso                     int64
# lesao_corp_morte              object
# latrocinio                     int64
# cvli                          object
# hom_por_interv_policial       object
# letalidade_violenta            int64
# tentat_hom                     int64
# lesao_corp_dolosa              int64
# estupro                       object
# hom_culposo                   object
# lesao_corp_culposa            object
# roubo_transeunte               int64
# roubo_celular                 object
# roubo_em_coletivo              int64
# roubo_rua                      int64
# roubo_veiculo                  int64
# roubo_carga                    int64
# roubo_comercio                 int64
# roubo_residencia               int64
# roubo_banco                    int64
# roubo_cx_eletronico           object
# roubo_conducao_saque          object
# roubo_apos_saque              object
# ...

# %% [markdown]
# As variáveis encontradas são do tipo `int` e `object`.
#
# Com essas informações iniciais, veremos como o `dataset` está organizado para decidirmos qual tipo de tratamento deveremos fazer nos dados.

# %%
# Primeiras 5 linhas do dataset
df.head()
# Out:
#     ano  mes  hom_doloso  ... pol_civis_mortos_serv  registro_ocorrencias fase
# 0  1991    1         657  ...                                                3
# 1  1991    2         732  ...                                                3
# 2  1991    3         713  ...                                                3
# 3  1991    4         634  ...                                                3
# 4  1991    5         650  ...                                                3
#
# [5 rows x 56 columns]

# %%
# Últimas 5 linhas do dataset
df.tail()
# Out:
#       ano  mes  hom_doloso  ... pol_civis_mortos_serv  registro_ocorrencias fase
# 359  2020   12         283  ...                     1                 47841    3
# 360  2021    1         361  ...                     0                 52352    2
# 361  2021    2         246  ...                     0                 49018    2
# 362  2021    3         313  ...                     0                 54306    2
# 363  2021    4         301  ...                     0                 47796    2
#
# [5 rows x 56 columns]

# %% [markdown]
# Nas cinco primeiras linhas observamos que o dataset possui entradas com campos em branco, geralmente quando um dataset possui dados faltantes, o próprio `pandas` atribui o valor `NaN` para valores ausentes, neste caso possui um espaço em branco que deve ser investigado e tratado.

# %%
# Soma dos valores nulos do dataset
(df.isnull().sum()).sort_values(ascending=False)
# Out:
# fase                          0
# registro_ocorrencias          0
# roubo_bicicleta               0
# roubo_apos_saque              0
# roubo_conducao_saque          0
# roubo_cx_eletronico           0
# roubo_banco                   0
# roubo_residencia              0
# roubo_comercio                0
# roubo_carga                   0
# roubo_veiculo                 0
# roubo_rua                     0
# roubo_em_coletivo             0
# roubo_celular                 0
# roubo_transeunte              0
# lesao_corp_culposa            0
# hom_culposo                   0
# estupro                       0
# lesao_corp_dolosa             0
# tentat_hom                    0
# letalidade_violenta           0
# hom_por_interv_policial       0
# cvli                          0
# latrocinio                    0
# lesao_corp_morte              0
# hom_doloso                    0
# mes                           0
# outros_roubos                 0
# total_roubos                  0
# ...

# %% [markdown]
# Apesar de termos campos em branco, o resultado do somátorio de dados ausentes é `0`. O que indica que este campo vazio, ou seja, pode estar preenchido com alguma coisa.
#
# O método `.info()` do Pandas nos mostra mais detalhes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ano                         364 non-null    int64
#  1   mes                         364 non-null    int64
#  2   hom_doloso                  364 non-null    int64
#  3   lesao_corp_morte            364 non-null    object
#  4   latrocinio                  364 non-null    int64
#  5   cvli                        364 non-null    object
#  6   hom_por_interv_policial     364 non-null    object
#  7   letalidade_violenta         364 non-null    int64
#  8   tentat_hom                  364 non-null    int64
#  9   lesao_corp_dolosa           364 non-null    int64
#  10  estupro                     364 non-null    object
#  11  hom_culposo                 364 non-null    object
#  12  lesao_corp_culposa          364 non-null    object
# ...

# %%
df.set_index('ano')
# Out:
#       mes  hom_doloso  ... registro_ocorrencias  fase
# ano                    ...
# 1991    1         657  ...                          3
# 1991    2         732  ...                          3
# 1991    3         713  ...                          3
# 1991    4         634  ...                          3
# 1991    5         650  ...                          3
# ...   ...         ...  ...                  ...   ...
# 2020   12         283  ...                47841     3
# 2021    1         361  ...                52352     2
# 2021    2         246  ...                49018     2
# 2021    3         313  ...                54306     2
# 2021    4         301  ...                47796     2
#
# [364 rows x 55 columns]

# %% [markdown]
# Por termos atributos do tipo `object` o pandas reconhece os valores em brancos como Strings, como se houvesse o caracter "espaço" neste campo, portanto, precisarão ser convertidos para o tipo numérico.
#
# O `Pandas` possui o método `replace()` que nos permite substituir determinados elementos do _DataFrame_ por outros, então substituiremos esses "espaços" pelo valor nulo `NaN` do `numpy`, no qual o `pandas` atribui os valores nulos.

# %%
# Substituindo os espaços em brancos por valores Nulos 

df.replace(r" ", np.nan, inplace=True)

# %% [markdown]
# Agora só precisamos converter essas variáveis do tipo `object` para o tipo `float`.

# %%
# Gerando uma lista com o nome dos atributos do tipo 'object'
features_obj = df.select_dtypes('object').columns

# Transformando esses atributos para o tipo float
df[features_obj] = df[features_obj].astype('float')

# %% [markdown]
# Se tudo correr de forma correta, a partir de agora poderemos visualizar os dados realmente faltantes do _dataset_.
#
# Checaremos a soma dos valores nulos novamente.

# %%
(df.isnull().sum()).sort_values(ascending=False)
# Out:
# furto_bicicleta               276
# roubo_bicicleta               276
# posse_drogas                  180
# cmba                          180
# cmp                           180
# aaapai                        180
# apf                           180
# apreensao_drogas_sem_autor    180
# trafico_drogas                180
# roubo_cx_eletronico           144
# roubo_apos_saque              144
# extorsao                      144
# sequestro_relampago           144
# estelionato                   144
# roubo_conducao_saque          144
# furto_celular                 144
# furto_coletivo                144
# estupro                       144
# pol_militares_mortos_serv     144
# pol_civis_mortos_serv         144
# pessoas_desaparecidas         132
# encontro_ossada               132
# roubo_celular                 108
# lesao_corp_culposa             96
# registro_ocorrencias           96
# sequestro                      96
# cvli                           96
# ...

# %% [markdown]
# Podemos ainda calcular a porcentagem de dados ausentes dos atributos para termos ciência do quão "comprometido", por assim dizer, esses atributos estão.

# %%
(df.isnull().mean()*100).sort_values(ascending=False).round(2)
# Out:
# furto_bicicleta               75.82
# roubo_bicicleta               75.82
# posse_drogas                  49.45
# cmba                          49.45
# cmp                           49.45
# aaapai                        49.45
# apf                           49.45
# apreensao_drogas_sem_autor    49.45
# trafico_drogas                49.45
# roubo_cx_eletronico           39.56
# roubo_apos_saque              39.56
# extorsao                      39.56
# sequestro_relampago           39.56
# estelionato                   39.56
# roubo_conducao_saque          39.56
# furto_celular                 39.56
# furto_coletivo                39.56
# estupro                       39.56
# pol_militares_mortos_serv     39.56
# pol_civis_mortos_serv         39.56
# pessoas_desaparecidas         36.26
# encontro_ossada               36.26
# roubo_celular                 29.67
# lesao_corp_culposa            26.37
# registro_ocorrencias          26.37
# sequestro                     26.37
# ...

# %%
df.head()
# Out:
#     ano  mes  hom_doloso  ...  pol_civis_mortos_serv  registro_ocorrencias  fase
# 0  1991    1         657  ...                    NaN                   NaN     3
# 1  1991    2         732  ...                    NaN                   NaN     3
# 2  1991    3         713  ...                    NaN                   NaN     3
# 3  1991    4         634  ...                    NaN                   NaN     3
# 4  1991    5         650  ...                    NaN                   NaN     3
#
# [5 rows x 56 columns]

# %%
# Plotando a porcentagem de dados ausentes
# Mostrando apenas os atributos com valores faltantes, descartando os demais.

fig, ax = plt.subplots(figsize=(14,10))

missing_percent = df.isnull().mean().sort_values(ascending=False).round(2)*100

# Filtrando valores de dados ausentes maiores que 0
missing_percent = missing_percent[missing_percent > 0]


# Configurações

valores = missing_percent.values
indices = missing_percent.index

# Plot
splot = sns.barplot(x=missing_percent.values,
                    y=missing_percent.index,
                    color=LARANJA,
                    ax=ax,
                    orient='h')

for p in splot.patches:
    width=p.get_width()

    if width >= 0.1:
        plt.text(p.get_width()-3, p.get_y()+0.55*p.get_height(),
                    '{}%'.format(width),
                    ha='center', va='center', color='white', size=11, fontweight='semibold')

        
ax.text(0,
        -1.7,
        "Porcentagem faltante dos atributos",
        color=CINZA_TITULO,
        size=22,
        fontweight="bold")

ax.set_xticklabels([], visible=False)
ax.yaxis.set_tick_params(left=False)
ax.xaxis.set_tick_params(bottom=False)

sns.despine(left=True, bottom=True);

# %% [markdown]
# Os valores do gráfico acima foram arredondados para melhor visualizarmos esses valores.
#
# Podemos ver alguns atributos com uma taxa de valores faltantes bastante alta como por exemplo os crimes relacionados a bicicletas e narcóticos.
#
# Entender o motivo desses dados ausentes poderá nos guiar para uma decisão melhor sobre como deveremos tratar esses dados.
#
# Podemos indagar algumas hipóteses para esses dados ausentes, tais como:
#
# * Esse tipo de crime realmente não aconteceu nesse período de tempo;
# * O tipo crime não foi registrado como deveria (sub-notificação);
# * O tipo de crime pode ter sido classificado como outra categoria;
# * O tipo de crime começou a ser contabilizado a partir de uma data específica.

# %% [markdown]
# ## Informações Estatísticas da Violência no Rio de Janeiro
#
# O método `describe()` nos permite visualizar um resmuo estatístico sobre o nosso _dataframe_, como:
# * Identificar _outliers_
# * Compreender melhor a distribuição dos dados.
# * Apontar falhas na distribuição dos dados.
# * Verificar a eficácia e a diferença entre os dados tratados e não tratados, logo após a limpeza dos dados.

# %%
# Gerando o resumo estatístico do DataFrame
df.describe()
# Out:
#                ano         mes  ...  registro_ocorrencias        fase
# count   364.000000  364.000000  ...            268.000000  364.000000
# mean   2005.670330    6.456044  ...          53641.123134    2.989011
# std       8.770166    3.465015  ...          10899.700086    0.104394
# min    1991.000000    1.000000  ...          30621.000000    2.000000
# 25%    1998.000000    3.000000  ...          45533.250000    3.000000
# 50%    2006.000000    6.000000  ...          54687.500000    3.000000
# 75%    2013.000000    9.000000  ...          63091.500000    3.000000
# max    2021.000000   12.000000  ...          75403.000000    3.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# ### Crimes contra o Patrimônio - Veículos
#
# Um dos crimes mais comuns são os relacionados a veículos. É um problema bastante recorrente nas metrópoles brasileiras e esta seção será dedicada a esse problema. Por termos dados sobre roubo, furto e recuperação de veículos, conseguiremos usar essas informações para nos situarmos sobre o resultado das ações de combate a esse tipo de crime.
#
# Antes de entrarmos em detalhes, devemos ressaltar a diferença entre _furto_ e _roubo_, pois de acordo com o [Tribunal de Justiça do Distrito Federal e dos Territórios](https://www.tjdft.jus.br/institucional/imprensa/campanhas-e-produtos/direito-facil/edicao-semanal/furto-e-roubo):
# * **Furto**: Subtração de um patrimônio sem que haja violência.
# * **Roubo**: Caracterizado como subtração do patrimônio sob grave ameaça ou violência.
#
# Veremos os valores para o roubo de veículos.

# %% [markdown]
# #### **Roubo de Veículos**

# %%
# Verificando os valores mínimo, máximo e a média por mês do atributo 'roubo_veiculo'
roubo_min = df.roubo_veiculo.min()
roubo_max = df.roubo_veiculo.max()
roubo_med = round(df.roubo_veiculo.mean(),2)

print("Roubo de veículos (Mínimo): ", roubo_min)
print("Roubo de veículos (Máximo): ", roubo_max)
print("Roubo de veículos (Média): ", roubo_med)
# Out:
# Roubo de veículos (Mínimo):  1097
# Roubo de veículos (Máximo):  5358
# Roubo de veículos (Média):  2440.91

# %%
fig, ax = plt.subplots(figsize=(5,3))


ax.text(0.0, 1, s=f'{round(roubo_med)}', size=80, color=LARANJA, fontweight='bold')
ax.text(0.0, 0.650, s='veículos são $\\bf{roubados}$\nem média por mês.', size=18, color=CINZA)

sns.despine(left=True, bottom=True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()

# %%
# Gerando o plot do atributo roubo_veiculo


fig, ax = plt.subplots(figsize=(12,8))

df_roubo = df.groupby('ano').sum()['roubo_veiculo']

ax.plot(df_roubo, linewidth=3, color=LARANJA)
ax.scatter(x=df_roubo.idxmax(), y=ax.get_ylim()[1]/1.05, linewidths=5,color=LARANJA)

ax.text(ax.get_xlim()[0],
        ax.get_ylim()[1]*1.15,
        "Roubos de veículos ao longo dos anos",
        size=22,
        color=CINZA,
        fontweight='bold')


ax.annotate(f"$\\bf{df_roubo.max()}$\nocorrências foram registradas\nem $\\bf{df_roubo.idxmax()}$",
            xy=(df_roubo.idxmax(), ax.get_ylim()[1]),
            xytext=(0,0),
            textcoords="offset points",
            color=LARANJA,
            size=18
            )
            
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
df_roubo = df.groupby('ano').sum()['roubo_veiculo']
df_roubo
# Out:
# ano
# 1991    16452
# 1992    24502
# 1993    24790
# 1994    27470
# 1995    23676
# 1996    18367
# 1997    19576
# 1998    21519
# 1999    29666
# 2000    27728
# 2001    28099
# 2002    34432
# 2003    33531
# 2004    32408
# 2005    32690
# 2006    34324
# 2007    31490
# 2008    27847
# 2009    25036
# 2010    20052
# 2011    18773
# 2012    22065
# 2013    28002
# 2014    32651
# 2015    31035
# 2016    41696
# 2017    54366
# 2018    52097
# 2019    39749
# 2020    25425
# 2021     8978
# Name: roubo_veiculo, dtype: int64

# %%
df_roubo.idxmax(),df_roubo.argmax(), df_roubo.max()
# Out:
# (2017, 26, 54366)

# %% [markdown]
# Procurando o maior e o menor número de registros de `roubo_veiculo`.

# %%
df.loc[df['roubo_veiculo'] == df.roubo_veiculo.max(), ['ano', 'mes', 'roubo_veiculo']]
# Out:
#       ano  mes  roubo_veiculo
# 326  2018    3           5358

# %%
df.loc[df['roubo_veiculo'] == df.roubo_veiculo.min(), ['ano', 'mes', 'roubo_veiculo']]
# Out:
#     ano  mes  roubo_veiculo
# 1  1991    2           1097

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,3))


ax[0].text(0.0, 1, s='5358', size=80, color=LARANJA, fontweight='bold')
ax[0].text(0.0, 0.650, s='veículos foram $\\bf{roubados}$ em\nMarço de 2018.', size=18, color=CINZA)

ax[1].text(0.0, 1, s='1097', size=80, color=LARANJA, fontweight='bold')
ax[1].text(0.0, 0.650, s='veículos foram $\\bf{roubados}$ em\nFevereiro de 1991.', size=18, color=CINZA)

ax[0].xaxis.set_visible(False)
ax[0].yaxis.set_visible(False)

ax[1].xaxis.set_visible(False)
ax[1].yaxis.set_visible(False)

sns.despine(left=True, bottom=True)
plt.tight_layout()

# %% [markdown]
# Analisando a variável `roubo_veiculo` vimos que em média **2241** veículos são roubados por mês, com o maior registro sendo **5358** em _Março de 2018_ e o menor registro sendo **1097** em _Fevereiro de 1991_.
#
# Observando o gráfico, vemos que a tendência de roubos aumenta durante um período e logo diminui, com um alto número de registros em 2018 e uma queda brusca de registros em 2020.

# %% [markdown]
# #### **Furto de Veículos**

# %%
# Fazendo a verificaçã do atributo 'furto_veiculo'
furto_min = df.furto_veiculos.min()
furto_max = df.furto_veiculos.max()
furto_med = round(df.furto_veiculos.mean(),2)

print("Furto de veículos (Mínimo): ", furto_min)
print("Furto de veículos (Máximo): ", furto_max)
print("Furto de veículos (Média): ", furto_med)
# Out:
# Furto de veículos (Mínimo):  904
# Furto de veículos (Máximo):  2630
# Furto de veículos (Média):  1643.92

# %%
fig, ax = plt.subplots(figsize=(8,3))


ax.text(0.0, 1, s=f'{round(furto_med)}', size=80, color=LARANJA, fontweight='bold')
ax.text(0.0, 0.650, s='veículos são $\\bf{furtados}$\nem média por mês.', size=18, color=CINZA)

sns.despine(left=True, bottom=True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12,8))


serie_furtos = df.groupby(by='ano').sum()['furto_veiculos']

ax.plot(serie_furtos, color=LARANJA, linewidth=3)
ax.scatter(serie_furtos.idxmax(), serie_furtos.max(), linewidths=5, color=LARANJA)

ax.text(ax.get_xlim()[0],
        ax.get_ylim()[1]*1.20,
        "Furtos de veículos ao longo dos anos",
        color=CINZA,
        size=22,
        fontweight='bold')

ax.annotate(f"$\\bf{serie_furtos.max()}$\nocorrências foram\nregistradas em $\\bf{serie_furtos.idxmax()}$",
            xy=(serie_furtos.idxmax(), ax.get_ylim()[1]),
            xytext=(25, -10),
            textcoords="offset points",
            color=LARANJA,
            size=14
            )


ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %% [markdown]
# Localizando o maior e o menor registro de `furto_veiculos`.

# %%
df.loc[df.furto_veiculos == df.furto_veiculos.max(), ['ano', 'mes', 'furto_veiculos']]
# Out:
#      ano  mes  furto_veiculos
# 38  1994    3            2630

# %%
df.loc[df.furto_veiculos == df.furto_veiculos.min(), ['ano', 'mes', 'furto_veiculos']]
# Out:
#       ano  mes  furto_veiculos
# 352  2020    5             904

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,3))


ax[0].text(0.0, 1, s=f"{df.furto_veiculos.max()}", size=80, color=LARANJA, fontweight='bold')
ax[0].text(0.0, 0.650, s='veículos foram $\\bf{furtados}$\nem Março de 1994.', size=18, color=CINZA)

ax[1].text(0.0, 1, s=f"{df.furto_veiculos.min()}", size=80, color=LARANJA, fontweight='bold')
ax[1].text(0.0, 0.650, s='veículos foram $\\bf{furtados}$\nem Maio de 2020.', size=18, color=CINZA)


ax[0].xaxis.set_visible(False)
ax[0].yaxis.set_visible(False)

ax[1].xaxis.set_visible(False)
ax[1].yaxis.set_visible(False)


sns.despine(left=True, bottom=True)
plt.tight_layout()

# %% [markdown]
# Os números de furto de veículo são relativamente menores em comparação aos roubos, porém, ainda altos. Em média, foram registrados 1646 furtos de veículos por mês, tendo 904 como o menor índice e 2630 como o maior índice de furtos.
#
#
#
# Fazendo uma comparação entre Roubos e Furtos de veículos.

# %%
fig, ax = plt.subplots(figsize=(12,8))


sns.lineplot(x='ano', y='furto_veiculos', data=df, ci=None, color=CINZA, linewidth=3)
sns.lineplot(x='ano', y='roubo_veiculo', data=df, ci=None, color=CINZA, linewidth=3)

# Título
ax.text(ax.get_xlim()[0],
        ax.get_ylim()[1]*1.10,
        "Furtos e Roubos de veículos ao longo do tempo",
        color=CINZA,
        size=22,
        fontweight="semibold")

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')


# Anotação das linhas
ax.annotate(f"{df.furto_veiculos.values[-1]}\nFurtos de Veículos",
            xy=(df.ano.max(), df.furto_veiculos.values[-1]),
            xytext=(10,-6),
            textcoords="offset points",
            size=18,
            fontweight="semibold",
            color=LARANJA
            )

ax.annotate(f"{df.roubo_veiculo.values[-1]}\nRoubos de Veículos",
            xy=(df.ano.max(), df.roubo_veiculo.values[-1]),
            xytext=(10,-2),
            textcoords="offset points",
            size=18,
            fontweight="semibold",
            color=LARANJA
            )

sns.despine()
plt.tight_layout()

# %% [markdown]
# Para se ter uma noção da eficiência do combate a esse tipo de crime, podemos analisar o atributo `recuperacao_veiculos` que nos informa a quantidade de veículos recuperados.
#
# Podemos ainda fazer um somatório de `furto_veiculos` com `roubo_veiculo` e comparar com `recuperacao_veiculos`.

# %%
# Verificando o atributo 'recuperacao_veiculos'

recuperacao_med = round(df.recuperacao_veiculos.mean(),2)
total_perdido = round(roubo_med + furto_med, 2)

print("\nVeículos Perdidos por Mês (Média): ", total_perdido)
print("Recuperação de Veículos por Mês (Média): ", recuperacao_med)

porcentagem_recuperada = round(recuperacao_med/total_perdido * 100,2)
print("{}% dos veículos furtados/roubados são recuperados.\n\n".format(porcentagem_recuperada))

fig, ax = plt.subplots(1,3 ,figsize=(12,3))

ax[0].text(0.0, 1, s=f'{round(total_perdido)}', size=60, color=LARANJA, fontweight='bold')
ax[0].text(0.0, 0.650, s='veículos são $\\bf{perdidos}$\nem média por mês.', size=18, color=CINZA)

ax[1].text(0.0, 1, s=f'{round(recuperacao_med)}', size=60, color=LARANJA, fontweight='bold')
ax[1].text(0.0, 0.650, s='veículos são $\\bf{recuperados}$\nem média por mês.', size=18, color=CINZA)

ax[2].text(0.0, 1, s=f'{round(porcentagem_recuperada)}%', size=60, color=LARANJA, fontweight='bold')
ax[2].text(0.0, 0.650, s='dos veículos são $\\bf{recuperados}$\nem média por mês.', size=18, color=CINZA)

ax[0].xaxis.set_visible(False)
ax[0].yaxis.set_visible(False)
ax[1].xaxis.set_visible(False)
ax[1].yaxis.set_visible(False)
ax[2].xaxis.set_visible(False)
ax[2].yaxis.set_visible(False)

sns.despine(left=True, bottom=True)

plt.tight_layout()
# Out:
# Veículos Perdidos por Mês (Média):  4084.83
# Recuperação de Veículos por Mês (Média):  1753.52
# 42.93% dos veículos furtados/roubados são recuperados.

# %%
fig, ax = plt.subplots(figsize=(12,8))
furtados_roubados = df['furto_veiculos'] + df['roubo_veiculo']

sns.lineplot(x='ano', y=furtados_roubados.values, data=df, ci=None, color=CINZA, linewidth=3)
sns.lineplot(x='ano', y='recuperacao_veiculos', data=df, ci=None, color=LARANJA, linewidth=3)

# Título
ax.text(ax.get_xlim()[0],
        ax.get_ylim()[1]*1.10,
        "Recuperação X Perda de Veículos",
        size=22,
        color=CINZA,
        fontweight="bold"
        )

# Anotação das linhas
ax.annotate(f"{int(furtados_roubados[-1:])}\nVeículos Perdidos",
            xy=(df.ano.max(), furtados_roubados[-1:]),
            xytext=(12,3),
            textcoords="offset points",
            size=14,
            fontweight="semibold",
            color=CINZA)

ax.annotate(f"{int(df.recuperacao_veiculos[-1:])}\nVeículos Recuperados",
            xy=(df.ano.max(), df.recuperacao_veiculos[-1:]),
            xytext=(12,-8),
            textcoords='offset points',
            size=14,
            fontweight="semibold",
            color=LARANJA
            )

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(12,8))


# Dados
furtados_roubados = df.groupby('ano').sum()[['furto_veiculos', 'roubo_veiculo']]
furtados_roubados = (furtados_roubados['furto_veiculos'] + furtados_roubados['roubo_veiculo']).cumsum()

recuperacao_veiculo = df.groupby('ano').sum()['recuperacao_veiculos'].cumsum()

# ---

ax.stackplot(furtados_roubados.index, furtados_roubados.values, color=CINZA)
ax.stackplot(recuperacao_veiculo.index, recuperacao_veiculo.values, color=LARANJA)

# Título
ax.text(ax.get_xlim()[0],
        ax.get_ylim()[1]*1.10,
        "Recuperação X Perda de Veículos",
        size=22,
        color=CINZA,
        fontweight="bold"
        )

# Anotação das linhas
ax.annotate(f"{furtados_roubados.max()}\nVeículos Perdidos",
            xy=(furtados_roubados.index.max(), furtados_roubados.max()),
            xytext=(12,-30),
            textcoords="offset points",
            size=18,
            fontweight="semibold",
            color=CINZA)

ax.annotate(f"{recuperacao_veiculo.max()}\nVeículos Recuperados",
            xy=(recuperacao_veiculo.index.max(), recuperacao_veiculo.max()),
            xytext=(12,-30),
            textcoords='offset points',
            size=18,
            fontweight="semibold",
            color=LARANJA
          )

lista_yticks = ["%.1fM" % x for x in np.arange(0, 1.6, 0.2)]

ax.set_xlim(xmin=recuperacao_veiculo.index.min(), xmax=recuperacao_veiculo.index.max())
ax.set_yticklabels(lista_yticks)
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
fig, ax = plt.subplots(1,2 ,figsize=(12,3))


ax[0].text(0.0, 1, s=f'1.48M', size=60, color=LARANJA, fontweight='bold')
ax[0].text(0.0, 0.550, s='de veículos foram $\\bf{perdidos}$\naproximadamente\ndesde 1991.', size=16, color=CINZA)

ax[1].text(0.0, 1, s='638 mil', size=60, color=LARANJA, fontweight='bold')
ax[1].text(0.0, 0.650, s='veículos foram $\\bf{recuperados}$\naproximadamente desde 1991.', size=16, color=CINZA)

ax[0].xaxis.set_visible(False)
ax[0].yaxis.set_visible(False)
ax[1].xaxis.set_visible(False)
ax[1].yaxis.set_visible(False)

sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# Podemos ainda extender a nossa análise para ver qual mês teve o maior número de registros de Roubos e Furtos.

# %%
# Qual mês possui o maior número de registros para ROUBO

fig, ax = plt.subplots(figsize=(12,10))


data_plot = df.set_index('ano').groupby(by='mes').sum()['roubo_veiculo']
x = data_plot.values
y = data_plot.index

bar_colors = [CINZA if (val < max(x)) else LARANJA for val in x]

splot = sns.barplot(x=x, 
                    y=y,
                    palette=bar_colors,
                    orient='h',
                    ax=ax);

for p in splot.patches:
    width=int(p.get_width())
    
   
    plt.text(p.get_width()/1.05,
             p.get_y()+0.55*p.get_height(),
            '{:d}'.format(width),
            ha="center", 
             va="center", 
             color="white", 
             size=14, 
             fontweight="semibold")


# Título
ax.text(x=ax.get_xlim()[0], 
        y=ax.get_ylim()[1]-0.75, 
        s="Histórico Mensal de Roubos de Veículos",
        size=22,
        color=CINZA,
        fontweight='bold')

# Comentário da barra
ax.annotate("$\\bf{Março}$ é o mês com\nmais registros.",
            xy=(ax.get_xlim()[1], data_plot.argmax()),
            xytext=(0,-12),
            textcoords='offset points',
            size=14,
            color=LARANJA,
            fontweight='medium')


ax.set_ylabel([],color='white')
ax.yaxis.set_ticklabels(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'])

ax.xaxis.set_visible(False)
ax.yaxis.set_tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %%
# Qual mês possui o maior número de registros para FURTOS

fig, ax = plt.subplots(figsize=(12,10))

data_plot = df.set_index('ano').groupby(by='mes').sum()['furto_veiculos']
x = data_plot.values
y = data_plot.index

bar_colors = [CINZA if (val < max(x)) else LARANJA for val in x]

splot = sns.barplot(x=x, 
                    y=y,
                    palette=bar_colors,
                    orient='h',
                    ax=ax);

for p in splot.patches:
    width=int(p.get_width())
    plt.text(p.get_width()/1.05, p.get_y()+0.55*p.get_height(),
             '{:d}'.format(width),
             ha='center', va='center', color='white', size=14, fontweight='semibold')


ax.text(x=ax.get_xlim()[0], y=ax.get_ylim()[1]-0.75,
        s="Histórico Mensal de Furtos de Veículos",
        size=22,
        fontweight="bold",
        color=CINZA)

ax.text(x=ax.get_xlim()[1], y=data_plot.argmax()+0.25,
        s='$\\bf{Março}$ é o mês com\nmais registros.', 
        fontweight='medium', 
        color=LARANJA,
        size=14)

ax.set_ylabel([],color='white')
ax.yaxis.set_ticklabels(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'])

ax.xaxis.set_visible(False)
ax.yaxis.set_tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %% [markdown]
# Para ambos, o mês de **Março** foi o mês com o maior número de registros de ocorrências.

# %% [markdown]
# ### Roubos e Furtos em geral
#
# Nesta etapa, analisaremos as variáveis relacionadas a Roubos e Furtos em geral encontradas na base de dados, tais como:
# - `roubo_transeunte`
# - `roubo_celular`
# - `roubo_em_coletivo`
# - `roubo_bicicleta`
# - `outros_roubos`
# - `furto_transeuntes`
# - `furto_coletivo`
# - `furto_celular`
# - `furto_bicicleta`
# - `outros_furtos`
#
# É importante mencionar, mais uma vez, a diferença entre **roubo** e **furto** para que não haja confusões entre os termos:
#
# - __Roubo__: Quando a vítima está ciente do ato, de que algo está sendo retirado de si sem sua permissão, ou seja, há o contato com o agressor, ou seja, mediante abordagem do agressor.
# - __Furto__: Quando a vítima não sabe e não vê o acontecimento.
#
# Iremos plotar os gráficos para cada tipo de roubo e furto e analisá-las.
#
# ---
#
#
# #### Roubos em Geral

# %%
fig,ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='roubo_transeunte', data=df, ci=None, linewidth=3, color=CINZA)
sns.lineplot(x='ano', y='roubo_celular', data=df, ci=None, linewidth=3, color=CINZA)
sns.lineplot(x='ano', y='roubo_em_coletivo', data=df, ci=None, linewidth=3, color=CINZA)
sns.lineplot(x='ano', y='roubo_bicicleta', data=df, ci=None, linewidth=3, color=CINZA)
sns.lineplot(x='ano', y='outros_roubos', data=df, ci=None, linewidth=3, color=CINZA)

ax.set_title('Roubos em Geral\n', size=22, loc='left', color=CINZA)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %% [markdown]
# Na seção a baixo, faremos uma análise um pouco mais detalhada sobre esses atributos.

# %% [markdown]
# #### Roubo a Transeuntes

# %%
fig, ax = plt.subplots(figsize=(12,8))


sns.lineplot(x='ano', y='roubo_transeunte', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='roubo_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_em_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_roubos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Roubo a Transeunte\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 3700, s='Roubo a\nTranseuntes', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de roubo_transeunte

df.loc[df.roubo_transeunte == df.roubo_transeunte.max(), ['ano', 'mes', 'roubo_transeunte']]
# Out:
#       ano  mes  roubo_transeunte
# 316  2017    5              9669

# %% [markdown]
# Roubo a transeunte teve um aumento significativo a partir de 2003 aproximadamente, com seu máximo de registros em Maio de 2017 com **9669** registros e um declínio considerável nos registros em 2020.
#
# É o tipo de roubo mais registros em comparação aos outros, seja talvez por se tratar de um tipo de roubo mais abrangente, que englobe o outros tipos de roubos como por exemplo, um roubo de mochila que continha celulares e outros pertences que foram registrados como roubo de transeuntes.

# %% [markdown]
# #### Roubo de Celulares

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='roubo_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_celular', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='roubo_em_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_roubos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Roubo de Celulares\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 1300, s='Roubo de Celulares', color=LARANJA, fontweight='bold')


ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de roubo_celular

df[df['roubo_celular'] == df.roubo_celular.max()][['ano', 'mes', 'roubo_celular']]
# Out:
#       ano  mes  roubo_celular
# 338  2019    3         2626.0

# %% [markdown]
# Inicialmente, sabe-se que os primeiros celulares surgiram no Brasil em 1990, entretanto podemos ver que os roubos de celulares começaram a ser registrados a partir do ano 2000, provavelmente por não ser tão comum uma pessoa possuir um celular na década de 90 e a popularidade do celular disparou a partir do ano 2000, essa categoria poderia estar englobada em outra categoria de roubo.
#
# Em Março de 2019 foi registrado o maior número de ocorrências de roubo de celulares com cerca de **2626** registros.

# %% [markdown]
# #### Roubo em Coletivos

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='roubo_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_em_coletivo', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='roubo_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_roubos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Roubo em Coletivos\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 990, s='Roubo em Coletivos', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de roubo em coletivo.

df.loc[df.roubo_em_coletivo == df.roubo_em_coletivo.max(), ['ano', 'mes', 'roubo_em_coletivo']]
# Out:
#       ano  mes  roubo_em_coletivo
# 319  2017    8               1628

# %% [markdown]
# Os roubos em coletivos seguem com uma taxa relativamente estável de registros, com o número máximo de **1628** ocorrências em Julho de 2017.

# %% [markdown]
# #### Roubo de Bicicleta

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(x='ano', y='roubo_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_em_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_bicicleta', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='outros_roubos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Roubo de Bicicleta\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 50, s='Roubo de Bicicleta', color=LARANJA, fontweight='bold')


ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %% [markdown]
# Os roubos de bicicletas só começaram a ser registrados a partir de 2014, entretanto são muito baixos em relação aos outros tipos de roubos, podemos dar um "zoom" nessa variável e observar sua variação desde quando ela começou a ser contabilizada.

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='roubo_bicicleta', data=df, ci=None, color=LARANJA, linewidth=3)

ax.set_title('Roubo de Bicicleta\n', size=22, loc='left', color=CINZA)

ax.text(2021.3, 25, s='Roubo de Bicicleta', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de roubo de bicicleta

df.loc[df.roubo_bicicleta == df.roubo_bicicleta.max(), ['ano', 'mes', 'roubo_bicicleta']]
# Out:
#       ano  mes  roubo_bicicleta
# 360  2021    1             41.0

# %% [markdown]
# Os roubos de bicicletas representam uma taxa extremamente baixa de registros desde que começou a ser contabilizada, vale ressaltar a hipótese de que esse registro possa estar sendo contabilizada como outra categória de roubo nos anos anteriores ao seu primeiro registro.
#
# O maior número de registros ocorreu em Janeiro de 2021 com **41** registros apenas.

# %% [markdown]
# #### Outros Roubos
#
# Nesta categória estão os registros que não estão relacionados a nenhuma das outras categórias mencionadas acima, entretanto, no dicionário de dados diz que esse atributo inclui a contagem de ocorrências de latrocínio.

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(x='ano', y='roubo_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_em_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='roubo_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_roubos', data=df, ci=None, color=LARANJA, linewidth=3)

ax.set_title('Outros tipos de Roubos\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 1380, s='Outros Roubos', color=LARANJA, fontweight='bold')



ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de outros roubos

df.loc[df.outros_roubos == df.outros_roubos.max(), ['ano', 'mes', 'outros_roubos']]
# Out:
#       ano  mes  outros_roubos
# 314  2017    3           3661

# %% [markdown]
# Na categoria de outros roubos, a maior taxa registrada foi em Março de 2017, com 3661 ocorrências.

# %% [markdown]
# #### Furtos a Transeuntes
#
# Primeiramente veremos o gráfico de Furtos de modo geral e analisaremos cada categoria após.

# %%
# Plotando Furtos em Geral

fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='furto_transeunte', data=df, ci=None, color=CINZA)
sns.lineplot(x='ano', y='furto_celular', data=df, ci=None, color=CINZA)
sns.lineplot(x='ano', y='furto_coletivo', data=df, ci=None, color=CINZA)
sns.lineplot(x='ano', y='furto_bicicleta', data=df, ci=None, color=CINZA)
sns.lineplot(x='ano', y='outros_furtos', data=df, ci=None, color=CINZA)

ax.set_title('Furtos em Geral\n', size=22, loc='left', color=CINZA)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %% [markdown]
# É possível ver que uma categoria de furtos se destaca das demais pela quantidade de registros feitos.
#
# Algumas ainda só começaram a ser registradas a partir de certa data, veremos isso mais adiante.

# %%
# Gráfico de Furto a Transeunte

fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(x='ano', y='furto_transeunte', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='furto_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_furtos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Furtos a Transeunte\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 620, s='Furtos a Transeunte', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# # Período com o registro máximo de furto_transeunte

df.loc[df.furto_transeunte == df.furto_transeunte.max(), ['ano', 'mes', 'furto_transeunte']]
# Out:
#       ano  mes  furto_transeunte
# 253  2012    2              5368

# %% [markdown]
# Os números de furtos a transeutes apresentou um crescimento a partir de 2004, atingindo o número máximo de ocorrências em Fevereiro de 2012 com **5368** ocorrências.

# %% [markdown]
# #### Furtos de Celulares

# %%
# Gráfico de Furto de Celulares

fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='furto_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_celular', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='furto_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_furtos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Furtos de Celulares\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 850, s='Furtos de Celulares', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Checando em qual ano os furtos de celulares começaram a ser contabilizados

df.set_index('mes').groupby('ano')['furto_celular'].count()
# Out:
# ano
# 1991     0
# 1992     0
# 1993     0
# 1994     0
# 1995     0
# 1996     0
# 1997     0
# 1998     0
# 1999     0
# 2000     0
# 2001     0
# 2002     0
# 2003    12
# 2004    12
# 2005    12
# 2006    12
# 2007    12
# 2008    12
# 2009    12
# 2010    12
# 2011    12
# 2012    12
# 2013    12
# 2014    12
# 2015    12
# 2016    12
# 2017    12
# 2018    12
# 2019    12
# 2020    12
# 2021     4
# Name: furto_celular, dtype: int64

# %% [markdown]
# Mostrando o gráfico de Furtos de Celulares isolado dos demais para melhorar a visualização desse atributo.

# %%
# Gráfico de Furto de Celulares

fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='furto_celular', data=df, ci=None, color=LARANJA, linewidth=3)

ax.set_title('Furtos de Celulares\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 980, s='Furtos de Celulares', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de furto_celular

df.loc[df.furto_celular == df.furto_celular.max(), ['ano', 'mes', 'furto_celular']]
# Out:
#       ano  mes  furto_celular
# 349  2020    2         2270.0

# %% [markdown]
# Os furtos de celulares começaram a ser registrados a partir de 2003, com seu pico em média de registros por volta de 2010, entretanto, o maior registro já feito ocorreu em Fevereiro de 2020 com **2270** ocorrências.

# %% [markdown]
# #### Furtos em Coletivos

# %%
# Gráfico de Furto em Coletivos

fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='furto_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_coletivo', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='furto_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_furtos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Furtos em Coletivos\n', size=22, loc='left', color=CINZA)
ax.text(2021.5, 375, s='Furtos em Coletivos', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Checando em qual ano os furtos em coletivos começaram a ser contabilizados

df.set_index('mes').groupby('ano')['furto_coletivo'].count()
# Out:
# ano
# 1991     0
# 1992     0
# 1993     0
# 1994     0
# 1995     0
# 1996     0
# 1997     0
# 1998     0
# 1999     0
# 2000     0
# 2001     0
# 2002     0
# 2003    12
# 2004    12
# 2005    12
# 2006    12
# 2007    12
# 2008    12
# 2009    12
# 2010    12
# 2011    12
# 2012    12
# 2013    12
# 2014    12
# 2015    12
# 2016    12
# 2017    12
# 2018    12
# 2019    12
# 2020    12
# 2021     4
# Name: furto_coletivo, dtype: int64

# %% [markdown]
# Mostrando o gráfico de Furtos em Coletivos isolado dos demais para melhorar a visualização.

# %%
# Gráfico de Furto em Coletivos

fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(x='ano', y='furto_coletivo', data=df, ci=None, color=LARANJA, linewidth=3)

ax.set_title('Furtos em Coletivos\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 390, s='Furtos em Coletivos', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de furto_coletivo

df.loc[df.furto_coletivo == df.furto_coletivo.max(), ['ano', 'mes', 'furto_coletivo']]
# Out:
#       ano  mes  furto_coletivo
# 256  2012    5          1036.0

# %% [markdown]
# Assim como os furtos de celulares e diferente dos roubos em coletivos, os furtos em coletivos começaram a serem registrados a partir de 2003, com sua máxima registrada em Maio de 2012 com **1036** registros.

# %% [markdown]
# #### Furtos de Bicicletas

# %%
# Gráfico de Furto de Bicicletas

fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='furto_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_bicicleta', data=df, ci=None, color=LARANJA, linewidth=3)
sns.lineplot(x='ano', y='outros_furtos', data=df, ci=None, color=CINZA, linewidth=0.8)

ax.set_title('Furtos de Bicicletas\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 100, s='Furtos de Bicicletas', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %% [markdown]
# Mostrando apenas o gráfico de Furtos de Bicicletas para melhor visualizar o atributo.

# %%
# Gráfico de Furto em Coletivos

fig, ax = plt.subplots(figsize=(12,8))
sns.lineplot(x='ano', y='furto_bicicleta', data=df, ci=None, color=LARANJA, linewidth=3)

ax.set_title('Furtos de Bicicletas\n', size=22, loc='left', color=CINZA)

ax.text(2021.25, 160, s='Furtos de Bicicletas', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de furto_bicicleta

df.loc[df.furto_bicicleta == df.furto_bicicleta.max(), ['ano', 'mes', 'furto_bicicleta']]
# Out:
#       ano  mes  furto_bicicleta
# 348  2020    1            278.0

# %%
df.set_index('mes').groupby('ano').sum()['furto_bicicleta'].dropna()
# Out:
# ano
# 1991       0.0
# 1992       0.0
# 1993       0.0
# 1994       0.0
# 1995       0.0
# 1996       0.0
# 1997       0.0
# 1998       0.0
# 1999       0.0
# 2000       0.0
# 2001       0.0
# 2002       0.0
# 2003       0.0
# 2004       0.0
# 2005       0.0
# 2006       0.0
# 2007       0.0
# 2008       0.0
# 2009       0.0
# 2010       0.0
# 2011       0.0
# 2012       0.0
# 2013       0.0
# 2014       0.0
# 2015    1086.0
# 2016    2013.0
# 2017    1924.0
# 2018    1901.0
# 2019    2470.0
# 2020    1785.0
# 2021     635.0
# Name: furto_bicicleta, dtype: float64

# %% [markdown]
# Assim como o roubo de bicicletas, os furtos só começaram a serem registrados a partir de 2014, entretanto, até 2014, nenhum registro havia sido feito para furto de bicicleta. É importante ressaltar a hipótese de que nos anos anteriores a 2014, os furtos e roubos de bicicletas poderiam está registrados em uma categória diferente.
#
#
# A maior média registrada de furtos foi para o ano de 2019 com **2470** ocorrências, enquanto o maior número de registros ocorreu em Janeiro de 2020 com **278** ocorrências.

# %% [markdown]
# #### Outros Furtos
#
# Assim como os roubos, a categoria `outros_furtos` englobam os furtos que não estão listados do dicionário de dados.

# %%
# Gráfico de Outros Furtos

fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='furto_transeunte', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_celular', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_coletivo', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='furto_bicicleta', data=df, ci=None, color=CINZA, linewidth=0.8)
sns.lineplot(x='ano', y='outros_furtos', data=df, ci=None, color=LARANJA, linewidth=3)

ax.set_title('Outros Furtos\n', size=22, loc='left', color=CINZA)

ax.text(2021.5, 5500, s='Outros Furtos', color=LARANJA, fontweight='bold')

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de outros_furtos

df.loc[df.outros_furtos == df.outros_furtos.max(), ['ano', 'mes', 'outros_furtos']]
# Out:
#       ano  mes  outros_furtos
# 276  2014    1           9880

# %%
df.outros_furtos.mean()
# Out:
# 5997.766483516483

# %% [markdown]
# Outros Furtos representa o maior número de registros entre os outros tipos de furtos, com uma média de 5999 registros e com sua máxima de **9880** registros em  Janeiro de 2014.

# %% [markdown]
# #### Visão Geral sobre Roubos e Furtos de Rua
#
# O dataset possui o atributo `roubo_rua` que nada mais é do que o somatório de _Roubo a transeunte + Roubo de celular + Roubo em coletivo_, entretanto não temos este mesmo atributo para os furtos, mas podemos criá-lo usando a mesma lógica usada para o atributo `roubo_rua` e depois poderemos fazer algumas comparações entre elas.
#
# Primeiro, vamos ver o atributo `roubo_rua`.

# %%
# Gráfico de Roubo de Rua

fig, ax = plt.subplots(figsize=(12,8))
roubo_de_rua = df.groupby(by='ano').sum()['roubo_rua']

ax.plot(roubo_de_rua, color=LARANJA, linewidth=3)

ax.text(ax.get_xlim()[0],
        ax.get_ylim()[1]*1.15,
        'Roubos de Rua ao longo dos anos',
        weight='bold',
        size=22,
        color=CINZA)

ax.scatter(roubo_de_rua.idxmax(), roubo_de_rua.max(), linewidths=5, color=LARANJA)

ax.annotate(f'$\\bf{roubo_de_rua.max()}$ roubos foram\nregistradas em $\\bf{roubo_de_rua.idxmax()}$.',
            xy=(roubo_de_rua.idxmax(), ax.get_ylim()[1]),
            size=14,
            color=LARANJA,
            fontweight='medium'
            )

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de roubo_rua

df.loc[df.roubo_rua == df.roubo_rua.max(), ['ano', 'mes', 'roubo_rua']]
# Out:
#       ano  mes  roubo_rua
# 316  2017    5      13833

# %%
df.groupby('ano').mean()['roubo_rua']
# Out:
# ano
# 1991     1278.250000
# 1992     1302.000000
# 1993     1208.500000
# 1994     1367.666667
# 1995     1375.583333
# 1996     1482.583333
# 1997     1673.833333
# 1998     1441.250000
# 1999     1712.166667
# 2000     2470.333333
# 2001     2967.500000
# 2002     3141.666667
# 2003     3055.750000
# 2004     3319.666667
# 2005     4361.500000
# 2006     5388.750000
# 2007     6444.750000
# 2008     7214.500000
# 2009     7374.583333
# 2010     6544.666667
# 2011     5544.583333
# 2012     4896.916667
# 2013     6021.333333
# 2014     7961.083333
# 2015     7106.666667
# 2016    10591.500000
# 2017    10470.500000
# 2018    10885.000000
# 2019    10039.250000
# 2020     5996.166667
# 2021     6123.750000
# Name: roubo_rua, dtype: float64

# %%
df.groupby('ano').sum()['roubo_rua']
# Out:
# ano
# 1991     15339
# 1992     15624
# 1993     14502
# 1994     16412
# 1995     16507
# 1996     17791
# 1997     20086
# 1998     17295
# 1999     20546
# 2000     29644
# 2001     35610
# 2002     37700
# 2003     36669
# 2004     39836
# 2005     52338
# 2006     64665
# 2007     77337
# 2008     86574
# 2009     88495
# 2010     78536
# 2011     66535
# 2012     58763
# 2013     72256
# 2014     95533
# 2015     85280
# 2016    127098
# 2017    125646
# 2018    130620
# 2019    120471
# 2020     71954
# 2021     24495
# Name: roubo_rua, dtype: int64

# %% [markdown]
# Os roubos de rua apresentaram um crescimento contínuo a partir do ano 2000, com uma queda na média de ocorrências pelos anos de 2010 a 2012, mas logo de volta a uma crescente atigindo o máximo de registros em **2018** com **130.620** ocorrências registradas nesse ano. Em **Maio de 2017** ocorreu o maior número de registros em um mês com **13.833** ocorrências registradas.

# %% [markdown]
# Criando o atributo `furtos_rua`, que é o somatório de `furto_transeunte` + `furto_coletivo` + `furto_celular`.

# %%
df['furto_rua'] = df.loc[:, ['furto_transeunte', 'furto_coletivo', 'furto_celular']].sum(axis=1).astype('int32')
df['furto_rua']
# Out:
# 0      1147
# 1      1066
# 2      1062
# 3      1195
# 4       723
#        ...
# 359    2143
# 360    2305
# 361    2124
# 362    2136
# 363    1799
# Name: furto_rua, Length: 364, dtype: int32

# %%
# Gráfico de Furto de Rua

fig, ax = plt.subplots(figsize=(12,8))

furtos_de_rua = df.groupby(by='ano').sum()['furto_rua']

ax.plot(furtos_de_rua, color=LARANJA, linewidth=3)

ax.text(ax.get_xlim()[0],
        ax.get_ylim()[1]*1.15,
        "Furtos de Rua ao longo dos anos",
        size=22,
        color=CINZA,
        fontweight="bold")

ax.annotate(f"$\\bf{furtos_de_rua.max()}$ furtos foram\nregistrados em $\\bf{furtos_de_rua.idxmax()}$",
            xy=(furtos_de_rua.idxmax(), furtos_de_rua.max()),
            xytext=(12,0),
            textcoords="offset points",
            size=14,
            color=LARANJA)

ax.scatter(x=furtos_de_rua.idxmax(),
           y=furtos_de_rua.max(),
           color=LARANJA,
           linewidth=3)

sns.despine()
plt.tight_layout()

# %%
# Período com o registro máximo de furto_rua

df.loc[df.furto_rua == df.furto_rua.max(), ['ano', 'mes', 'furto_rua']]
# Out:
#       ano  mes  furto_rua
# 253  2012    2       8117

# %%
df.groupby('ano').mean()['furto_rua']
# Out:
# ano
# 1991     912.000000
# 1992     866.833333
# 1993     624.000000
# 1994     576.416667
# 1995     534.500000
# 1996     815.333333
# 1997     802.416667
# 1998     473.916667
# 1999     449.083333
# 2000     774.916667
# 2001     703.250000
# 2002     850.416667
# 2003    1458.000000
# 2004    1729.666667
# 2005    2694.500000
# 2006    3690.500000
# 2007    4062.916667
# 2008    4652.083333
# 2009    4937.000000
# 2010    5317.500000
# 2011    5543.000000
# 2012    5276.916667
# 2013    5270.666667
# 2014    5183.416667
# 2015    5692.416667
# 2016    4758.416667
# 2017    3527.583333
# 2018    3706.166667
# 2019    3876.666667
# 2020    2187.083333
# 2021    2091.000000
# Name: furto_rua, dtype: float64

# %%
df.groupby('ano').sum()['furto_rua']
# Out:
# ano
# 1991    10944
# 1992    10402
# 1993     7488
# 1994     6917
# 1995     6414
# 1996     9784
# 1997     9629
# 1998     5687
# 1999     5389
# 2000     9299
# 2001     8439
# 2002    10205
# 2003    17496
# 2004    20756
# 2005    32334
# 2006    44286
# 2007    48755
# 2008    55825
# 2009    59244
# 2010    63810
# 2011    66516
# 2012    63323
# 2013    63248
# 2014    62201
# 2015    68309
# 2016    57101
# 2017    42331
# 2018    44474
# 2019    46520
# 2020    26245
# 2021     8364
# Name: furto_rua, dtype: int32

# %% [markdown]
# O crescimento da média de furtos de rua ocorreu a partir de 2002 e somente a partir de 2016 começou o declínio na média de ocorrências. Enquanto o máximo de ocorrências registrado em um ano foi em 2015 com **68.309** registros e para o número máximo de registros para o mês foi em Fevereiro de 2012 com **8117** registros.

# %% [markdown]
# #### Comparação entre os Furtos e Roubos de Rua

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='roubo_rua', data=df, ci=None, color=CINZA, linewidth=2)
sns.lineplot(x='ano', y='furto_rua', data=df, ci=None, color=CINZA, linewidth=2)

ax.set_title('Furtos e Roubos de Rua ao longo do tempo\n', 
             size=22, 
             loc='left',
             fontweight='semibold',
             color=CINZA)

ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

ax.text(2021.5, 2000, s='Furtos de Rua', color=LARANJA, fontweight='bold')
ax.text(2021.5, 6200, s='Roubos de Rua', color=LARANJA, fontweight='bold')

sns.despine()
plt.tight_layout()

# %% [markdown]
# Os números de Roubos permaneceram superiores a Furtos durante a maior parte do histórico de registros, apenas entre os anos 2010 a 2013 que os números de Roubos diminuiram, fazendo com que os números de Furtos fossem um pouco superiores aos números de Roubos neste período, mas logo voltaram a aumentar novamente.
#
# Podemos ainda fazer o somatório de ocorrências por mês e ver qual mês possui mais registros de ocorrências.

# %%
# Qual mês possui o maior número de registros para FURTOS DE RUA?

fig, ax = plt.subplots(figsize=(12,10))

data_plot = df.set_index('ano').groupby(by='mes').sum()['furto_rua']
x = data_plot.values
y = data_plot.index

bar_colors = [CINZA if (val < max(x)) else LARANJA for val in x]

splot = sns.barplot(x=x, 
                    y=y,
                    palette=bar_colors,
                    orient='h',    
                    ax=ax);

for p in splot.patches:
    width=int(p.get_width())
    plt.text(p.get_width()/1.07, p.get_y()+0.55*p.get_height(),
             '{:d}'.format(width),
             ha='center', va='center', color='white', size=14, fontweight='semibold')
    

ax.text(-1, -1,
        "Histórico Mensal de Furtos de Rua",
        color=CINZA,
        fontweight='bold',
        size=22)

ax.annotate("$\\bf{Fevereiro}$ é o mês\ncom mais registros.",
            xy=(x.max(), x.argmax()),
            xytext=(15,-10),
            textcoords="offset points",
            color=LARANJA
            )

ax.set_ylabel([],color='white')
ax.yaxis.set_ticklabels(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'])

ax.xaxis.set_visible(False)
ax.yaxis.set_tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %% [markdown]
# O Furtos de Rua atingiram o total de **98.351** registros de ocorrências no mês Fevereiro.

# %%
# Qual mês possui o maior número de registros para ROUBOS DE RUA?

fig, ax = plt.subplots(figsize=(12,10))

data_plot = df.set_index('ano').groupby(by='mes').sum()['roubo_rua']

x = data_plot.values
y = data_plot.index

bar_colors = [CINZA if (val < max(x)) else LARANJA for val in x]

splot = sns.barplot(x=x, 
                    y=y,
                    palette=bar_colors,
                    orient='h',
                    ax=ax);

for p in splot.patches:
    width=int(p.get_width())

    plt.text(p.get_width()/1.07, p.get_y()+0.55*p.get_height(),
             '{:d}'.format(width),
             ha='center',
             va='center',
             color='white',
             fontweight='semibold',
             size=14)
    

# Título
ax.text(x=ax.get_xlim()[0],
        y= ax.get_ylim()[1]-0.75,
        s="Histórico Mensal de Roubos de Rua",
        size=22,
        color=CINZA,
        fontweight="semibold")

# Comentário da barra
ax.annotate("$\\bf{Março}$ é o mês\ncom mais registros",
            xy=(x.max(), x.argmax()),
            xytext=(12,-11),
            textcoords="offset points",
            size=14,
            color=LARANJA
            )

ax.set_ylabel([],color='white')
ax.yaxis.set_ticklabels(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'])

ax.xaxis.set_visible(False)
ax.yaxis.set_tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %% [markdown]
# Março foi o mês que mais teve ocorrências registradas de Roubos de Rua com **155.906** registros.
#
#
# É interessante ressaltar o detalhe dos meses que possuem os maiores registros até aqui, sempre entre **Fevereiro** e **Março**, nesses meses acontece o maior festival do Brasil, o *Carnaval*. Podemos levantar a hipótese de que os números altos para esses meses possam estar correlacionados a este evento.

# %% [markdown]
# ### Crimes contra a Vida
#
# O _dataset_  possui o atributo `letalidade_violenta` que é o somatório dos seguintes crimes contra a vida:
#
#
# |Atributo|Descrição|
# |----------|-----------|
# | `hom_doloso` | Quando há a intenção ou se o agente assumiu o resultado de uma conduta criminosa|
# | `lesao_corp_morte`|   Lesão corporal seguida de morte |
# | `latrocinio`|     Latrocínio (roubo seguido de morte) |
# | `hom_por_interv_policial` | Morte por intervenção de agente do Estado |
#
# Analisaremos o atributo `letalidade_violenta` de modo geral.

# %%
# Valores min e max de 'letalidade_violenta'

max_letalidade = df.letalidade_violenta.max()
min_letalidade = df.letalidade_violenta.min()

print("Mínimo Registrado:\t", min_letalidade)
print("Máximo Registrado:\t", max_letalidade)
# Out:
# Mínimo Registrado:	 297
# Máximo Registrado:	 848

# %% [markdown]
# O menor número de casos registrados foi de 297 enquanto o maior número registrado foi de 848.
#
# Investigaremos um pouco mais a fundo esses registros.
#
# O `Pandas` possui o método `.query()` que funciona como uma query SQL. Usaremos esse método para encontrar esses registros.

# %%
# Realizando busca sobre o menor registro de 'letalidade_violenta'
# Para simplificar a visualização, selecionaremos apenas os atributos 'ano', 'mes' e 'letalidade_violenta'

df.query("letalidade_violenta == 297")[['mes', 'ano', 'letalidade_violenta']]
# Out:
#      mes   ano  letalidade_violenta
# 353    6  2020                  297

# %%
# Localizando o maior registro de 'letalidade_violenta'

df.query("letalidade_violenta == 848")[['mes', 'ano', 'letalidade_violenta']]
# Out:
#     mes   ano  letalidade_violenta
# 48    1  1995                  848

# %%
df.groupby('ano').mean()['letalidade_violenta']
# Out:
# ano
# 1991    643.583333
# 1992    660.250000
# 1993    665.416667
# 1994    719.250000
# 1995    719.833333
# 1996    618.750000
# 1997    586.666667
# 1998    517.500000
# 1999    535.666667
# 2000    582.750000
# 2001    590.250000
# 2002    670.250000
# 2003    671.166667
# 2004    637.083333
# 2005    665.583333
# 2006    637.416667
# 2007    641.583333
# 2008    594.500000
# 2009    592.166667
# 2010    485.666667
# 2011    413.333333
# 2012    388.833333
# 2013    445.666667
# 2014    476.583333
# 2015    417.500000
# 2016    521.833333
# 2017    562.416667
# 2018    559.500000
# 2019    498.333333
# 2020    408.916667
# 2021    467.750000
# Name: letalidade_violenta, dtype: float64

# %%
# Localizando a menor média de 'letalidade_violenta'

df.groupby('ano').mean()[['letalidade_violenta']].min()
# Out:
# letalidade_violenta    388.833333
# dtype: float64

# %%
fig, ax = plt.subplots(ncols=2,figsize=(8,3))

ax[0].text(0.0, 1, s='848', size=80, color=LARANJA, fontweight='bold')
ax[0].text(0.0, 0.500, s='crimes letais foi\no $\\bf{máximo}$ registrado\nem $\\bf{Janeiro\\ de\\ 1995}$.', size=16, color=CINZA)

ax[1].text(0.0, 1, s='297', size=80, color=LARANJA, fontweight='bold')
ax[1].text(0.0, 0.500, s='crimes letais foi\no $\\bf{mínimo}$ registrado\nem $\\bf{Junho\\ de\\ 2020}$.', size=16, color=CINZA)

ax[0].xaxis.set_visible(False)
ax[0].yaxis.set_visible(False)

ax[1].xaxis.set_visible(False)
ax[1].yaxis.set_visible(False)

sns.despine(left=True, bottom=True)
plt.tight_layout()

# %% [markdown]
# O mês de Janeiro de 1995 foi o mês com o maior número de registros de crimes letais no dataset, em contra partida, o mês de Junho de 2020 foi o registrado o menor número de casos.
#
# Isso nos diz que, a princípio, que esse tipo de crime tenha diminuindo com o passar dos anos. Somente uma análise mais detalhada poderá nos confirmar.

# %% [markdown]
# Um histograma é uma das ferramentas mais úteis e poderosas, ela nos ajuda a compreender a distribuição das variáveis numéricas de um dataset.
#
# Faremos uma análise do histograma do atribulo `letalidade_violenta`.

# %%
# Histograma de 'letalidade_violenta'
sns.set_theme(style="ticks")

fig, ax = plt.subplots(figsize=(12,8))
sns.despine(fig)

sns.histplot(df, x='letalidade_violenta', bins=25, linewidth=.5, color=LARANJA, ax=ax)
ax.set_title("Histograma de Letalidade Violenta\n", loc='left', size=22, color=CINZA, fontweight="semibold")
ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

plt.tight_layout()

# %% [markdown]
# Observando o histograma acima, podemos apontar que:
# * Houveram um pouco menos de 40 meses com mais de 600 registros ao longo do período em estudo.
# * Houveram menos de 5 meses ao longo do período do dataset com cerca de 300 a 350 e entre 800 e 850 registros aproximadamente.
# * A média se mantém em 570 registros aproximadamente por mês.
#
#
# Por último, utilizando o gráfico de linhas, veremos a evolução dos registros de crimes violentos ao longo do tempo.

# %%
fig, ax = plt.subplots(figsize=(12,8))

sns.lineplot(x='ano', y='letalidade_violenta', data=df, ci=None, color=LARANJA, linewidth=3)

ax.text(x=ax.get_xlim()[0],
        y=ax.get_ylim()[1]*1.05,
        s="Crimes Violentos ao longo dos anos",
        size=22,
        fontweight="semibold",
        color=CINZA)


ax.set_xlabel([], color='white')
ax.set_ylabel([], color='white')

sns.despine()
plt.tight_layout()

# %% [markdown]
# É interessante ressaltar que o ano de `2012` foi o ano que teve a menor média de crimes violentos e nos anos seguintes os números em média começaram a aumentar novamente até voltarem a cair de 2018 a 2020.

# %% [markdown]
# Podemos ver quais meses foram os mais violentos, os que mais tiveram registros de ocorrências de crimes violentos.

# %%
# Qual mês possui o maior número de registros para LETALIDADE VIOLENTA

fig, ax = plt.subplots(figsize=(12,8))

data_plot = df.set_index('ano').groupby(by='mes').sum()['letalidade_violenta']
x = data_plot.values
y = data_plot.index

bar_colors = [CINZA if (val < max(x)) else LARANJA for val in x]

ax.text(x=ax.get_xlim()[0],
        y=ax.get_ylim()[1]-2,
        s="Histórico Mensal de Crimes Violentos",
        color=CINZA, 
        size=22,
        fontweight="semibold")

splot = sns.barplot(x=x, 
                    y=y,
                    palette=bar_colors,
                    orient='h',
                    ax=ax);

for p in splot.patches:
    width=int(p.get_width())
    plt.text(p.get_width()/1.05,
             p.get_y()+0.55*p.get_height(),
             '{:d}'.format(width),
             ha='center',
             va='center',
             color='white',
             size=14,
             fontweight="semibold")

ax.annotate("$\\bf{Março}$ é o mês com\nmais registros.",
            xy=(x.max(), x.argmax()),
            xytext=(12,-12),
            textcoords="offset points",
            size=14,
            color=LARANJA)


ax.set_ylabel([], visible=False)
ax.yaxis.set_ticklabels(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'])

ax.xaxis.set_visible(False)
ax.yaxis.set_tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.tight_layout()

# %% [markdown]
# O mês de Março é o que mais registrou ocorrências de Crimes Violentos com **19.711** registros.

# %% [markdown]
# ### Total de Ocorrências
#
# O atributo `registro_ocorrencias` se refere ao total de registros de ocorrências divulgados no mês, podemos ver qual mês e qual ano que mais registrou ocorrências.

# %%
df.groupby('ano').sum()['registro_ocorrencias']
# Out:
# ano
# 1991         0.0
# 1992         0.0
# 1993         0.0
# 1994         0.0
# 1995         0.0
# 1996         0.0
# 1997         0.0
# 1998         0.0
# 1999    396839.0
# 2000    432470.0
# 2001    453577.0
# 2002    502333.0
# 2003    536163.0
# 2004    550262.0
# 2005    581416.0
# 2006    609251.0
# 2007    631684.0
# 2008    654745.0
# 2009    669716.0
# 2010    674047.0
# 2011    696275.0
# 2012    718733.0
# 2013    775129.0
# 2014    818727.0
# 2015    777356.0
# 2016    806042.0
# 2017    750607.0
# 2018    770467.0
# 2019    781522.0
# 2020    584988.0
# 2021    203472.0
# Name: registro_ocorrencias, dtype: float64

# %% [markdown]
# É possível ver que o registro de ocorrências só começou a ser contabilizado a partir de 1999, entretanto, podemos usar a mesma lógica usada para a criação de `registro_ocorrencias` e calcular o total de ocorrências  mensais para podermos calcular o total anual dos anos de 1991 a 1998.
#
# - Lógica Usada: **Total de registros de ocorrências divulgados no mês**

# %%
# Calculando o número de registros mensais para o ano de 1991
df.loc[df['ano'] == 1991].sum(axis=1)
# Out:
# 0     30339.0
# 1     29610.0
# 2     31302.0
# 3     31268.0
# 4     30029.0
# 5     28630.0
# 6     28404.0
# 7     28698.0
# 8     28333.0
# 9     30293.0
# 10    31126.0
# 11    32211.0
# dtype: float64

# %%
# Quantas linhas estão sem valores
df['registro_ocorrencias'].isna().sum()
# Out:
# 96

# %% [markdown]
# Essas 96 linhas que estão com os valores ausentes, se referem aos meses dos anos de 1991 a 1998. O código a seguir calculará os valores de registros de ocorrências por mês dos meses faltantes para serem adicionados os valores dos meses correspondentes do dataset.

# %%
# Gerando a série do Pandas com os valores faltantes dos registros de ocorrências mensais.

fill_values = pd.Series(df[:96].sum(axis=1).values)
fill_values
# Out:
# 0     30339.0
# 1     29610.0
# 2     31302.0
# 3     31268.0
# 4     30029.0
#        ...
# 91    35221.0
# 92    34621.0
# 93    35906.0
# 94    34650.0
# 95    36695.0
# Length: 96, dtype: float64

# %%
# Preenchendo os valores vazios com a lista dos valores

df['registro_ocorrencias'].fillna(fill_values, axis=0, inplace=True)

# %%
df.groupby('ano').sum()['registro_ocorrencias']
# Out:
# ano
# 1991    360243.0
# 1992    390063.0
# 1993    366758.0
# 1994    367767.0
# 1995    345441.0
# 1996    343818.0
# 1997    386509.0
# 1998    425322.0
# 1999    396839.0
# 2000    432470.0
# 2001    453577.0
# 2002    502333.0
# 2003    536163.0
# 2004    550262.0
# 2005    581416.0
# 2006    609251.0
# 2007    631684.0
# 2008    654745.0
# 2009    669716.0
# 2010    674047.0
# 2011    696275.0
# 2012    718733.0
# 2013    775129.0
# 2014    818727.0
# 2015    777356.0
# 2016    806042.0
# 2017    750607.0
# 2018    770467.0
# 2019    781522.0
# 2020    584988.0
# 2021    203472.0
# Name: registro_ocorrencias, dtype: float64

# %% [markdown]
# Com os valores devidamentes preenchidos, podemos gerar gráficos mais precisos.

# %%
# Gráfico de Ocorrências Mensais

fig, ax = plt.subplots(figsize=(12,10))

data_plot = df.set_index('ano').groupby(by='mes').sum()['registro_ocorrencias']
x = data_plot.values
y = data_plot.index

bar_colors = [CINZA if (val < max(x)) else LARANJA for val in x]

splot = sns.barplot(x=x, 
                    y=y,
                    palette=bar_colors,
                    orient='h',
                    ax=ax);

for p in splot.patches:
    width=int(p.get_width())
    plt.text(p.get_width()/1.075,
             p.get_y()+0.55*p.get_height(),
             '{:d}'.format(width),
             ha='center',
             va='center',
             color='white',
             size=14,
             fontweight="semibold")

ax.text(x=ax.get_xlim()[0],
        y=ax.get_ylim()[1]-0.75,
        s="Histórico de Registros de Ocorrências Mensais",
        size=22,
        color=CINZA,
        fontweight="semibold")


ax.annotate("$\\bf{Março}$ é o mês\ncom $\\bf{mais}$ registros.",
            xy=(x.max(), x.argmax()),
            xytext=(12,-14),
            textcoords="offset points",
            color=LARANJA,
            size=14)

ax.set_ylabel([],visible=False)
ax.yaxis.set_ticklabels(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'])

ax.xaxis.set_visible(False)
ax.yaxis.set_tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %%
# Texto do Mês com mais ocorrências

fig, ax = plt.subplots(figsize=(5,3))

ax.text(0.0, 1, s='1.55M', size=60, color=LARANJA, fontweight='bold')
ax.text(0.0, 0.650, s='ocorrências registradas\npara o mês de', size=18, color=CINZA)
ax.text(0.415, 0.650, s='Março', size=18, color=LARANJA)

sns.despine(left=True, bottom=True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()

# %%
# Gráfico de Ocorrências Anuais

fig, ax = plt.subplots(figsize=(10, 14))

data_plot = df.groupby(by='ano').sum()['registro_ocorrencias']
x = data_plot.values
y = data_plot.index

bar_colors = [CINZA if (val < max(x)) else LARANJA for val in x]


splot = sns.barplot(x=x, 
                    y=y,
                    palette=bar_colors,
                    orient='h',
                    ci=None,
                    ax=ax);

for p in splot.patches:
    width=int(p.get_width())
    plt.text(p.get_width()-60000,
             p.get_y()+0.55*p.get_height(),
             '{:d}'.format(width),
             ha='center',
             va='center',
             color='white',
             size=12,
             fontweight="semibold")

ax.text(x=ax.get_xlim()[0],
        y=ax.get_ylim()[1]*3.0,
        s="Total de Ocorrências Anuais",
        size=22,
        fontweight="semibold",
        color=CINZA)

ax.annotate(s="$\\bf{2014}$ foi o ano\ncom mais $\\bf{Ocorrências}$.",
            xy=(x.max(), x.argmax()),
            xytext=(12,-10),
            textcoords="offset points",
            color=LARANJA,
            size=14
            )

ax.set_ylabel([],color='white')


ax.xaxis.set_visible(False)
ax.yaxis.set_tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %%
# Texto sobre o ano com mais ocorrências
fig, ax = plt.subplots(figsize=(5,3))

ax.text(0.0, 1, s='819 mil', size=60, color=LARANJA, fontweight='bold')
ax.text(0.0, 0.650, s='ocorrências registradas\nem', size=18, color=CINZA)
ax.text(0.105, 0.650, s='2014', size=18, fontweight="semibold", color=LARANJA)

sns.despine(left=True, bottom=True)
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.tight_layout()

# %%
# Gráfico de Registros de Ocorrências

fig, ax = plt.subplots(figsize=(12,8))

# Gerando os dados do gráfico
tot_ocorrencias = df.groupby(by="ano").sum()['registro_ocorrencias']

# Plotando o gráfico
ax.plot(tot_ocorrencias.index, 
        tot_ocorrencias.values,
        color=LARANJA,
        linewidth=3)

# Título do Gráfico
ax.text(x=ax.get_xlim()[0],
        y=ax.get_ylim()[1]*1.05,
        s="Total de Ocorrências Anuais",
        size=22,
        color=CINZA,
        fontweight="semibold")


# Scatter plot no maior valor registrado
ax.scatter(x=tot_ocorrencias.idxmax(), 
           y=tot_ocorrencias.max(),
           color=LARANJA,
           linewidth=5)

# Anotação no maior valor do gráfico
ax.annotate(s=f"$\\bf{int(tot_ocorrencias.max())}$ ocorrências foram\nregistradas em $\\bf{tot_ocorrencias.idxmax()}$.",
            xy=(tot_ocorrencias.idxmax(), tot_ocorrencias.max()),
            xytext=(0,15),
            textcoords="offset points",
            size=14,
            color=LARANJA)

# Configuração extra (removendo os nomes dos eixos x e y)
ax.set_xlabel([], visible=False)
ax.set_ylabel([], visible=False)

sns.despine()
plt.tight_layout()

# %% [markdown]
# No gráfico acima, podemos ver que o <b>número de ocorrências</b> começou a evoluir constantemente a partir de <b>1999</b> chegando a máxima já registrada em <b>2014</b> com aproximadamente <b>819 mil</b> ocorrências registradas mas após essa máxima, os números apresentaram uma tendência de queda a partir de 2019.
#
# Apesar de demonstrar uma tendência de queda, o dataset possui dados até o mês de Março de 2021 então é esperado essa "queda" abrupta no final do gráfico pois ainda não havia registros para os meses restantes do ano de 2021, <b><i>então não devemos tirar conclusões precipitadas em relação a esses dados.</b></i>

# %% [markdown]
# ## Conclusão
#
# Mesmo se tratando de `dataset` relativamente pequeno e simples de lidar, tivemos que fazer um tratamento e limpeza de dados em alguns campos que estava de forma "incorreta" ou com valores faltantes.
#
# Analisando os dados sobre diversos tipos de crimes contra o patrimônio e com os dados sobre crimes contra a vida, pudemos concluir que:
# <i><b>
# - Um pouco menos da metade dos carros perdidos em Furtos ou Roubos são recuperados.
# - Alguns dados começaram a serem registrados após uma determinada data, o que não implica que este tipo de ocorrência não acontecia antes, eles poderiam estar sendo registrados em outra categoria de crime, como o caso dos roubos e furtos de bicicletas, que só começaram a ser registrados a partir de 2014.
# - Os números de Roubos apresentam uma leve crescente a partir do ano de 2010, diferente dos números de Furtos que começaram a seguir uma diminuição a partir de 2010.
# - Os números de Roubos permaneceam superiores aos números de Furtos.
# - Os crimes violentos foram variando com altos e baixos ao longo dos anos, mas com tendência a diminuir.
# </i></b>
#
# É interessante voltar a atenção a um detalhe encontrado na análise, os meses que mais se destacaram tanto em questão de roubos/furtos e crimes contra a vida, foram os meses de **Fevereiro** e **Março**, o que implica que, nesse período de tempo, ocorre a realização do [*Carnaval*](https://pt.wikipedia.org/wiki/Carnaval), onde o fluxo de turístas aumenta consideravelmente durante esse período que por sua vez, possa estar correlacionado com os altos valores que esses meses atingiram em comparação aos outros meses.
#
# Outro detalhe importante que deve ser ressaltado é a queda súbita de crimes durante o ano de 2020. Durante esse ano, o mundo se encontrava diante de uma pandemia e no Brasil, diversos estados decretaram o regime de *lockdown*, que reduz a circulação de pessoas nas ruas durante o período em que esse regime esteja em vigor. O baixo fluxo de pessoas circulando pela cidade pode ter influenciado na quantidade de ocorrências registradas para o ano de 2020.
#
# Em uma análise inicial e de modo geral, pudemos obter interessantes `insights` sobre a evolução da violência no Rio de Janeiro entre o período de 1991 até o começo de 2021, que ainda nos abre um leque de opções para futuras análises mais detalhadas desse `dataset`.
#
#
#
# ---
# <br>
#
# Se houver alguma crítica, dica ou sugestão, entre em contato:
#
# [LinkedIn](https://www.linkedin.com/in/roberto-paixao95/)
